# %% [markdown]
# ## Workstation

# %%
#Imports
import requests
from bs4 import BeautifulSoup
import re
import wikipedia
import time
import json
from typing import List

# %%
#Helper functions
def join_contents_from_json(file_names: List[str], new_output_file_name: str, rmv_old_files: bool=False):
    """
    take two output files from ArticleConnections.get_data() and join them to one file
    """
    new_dict = {}
    for file_name in file_names:
        data = json_to_dict(file_name)
        new_dict.update(data)
    write_data_to_json(new_dict, new_output_file_name)
    if rmv_old_files:
        print('have not implemented removing old files yet')
    return new_dict

def write_data_to_json(data: dict, new_output_file_name: str) -> None:
    """
    Take dictionary to write it to a json file.
    """
    with open(new_output_file_name, mode="w") as f:
        json.dump(data, f)
    print(f"writing your data to {new_output_file_name}")

def json_to_dict(file_name):
    """
    Get dictionary obj from json file.
    """
    with open("outputs/get_data_Imaginary_number_100.json", mode="r") as f:
        return json.load(f)

# %%
#Globals
# BASE_WIKIPEDIA_URL = "https://simple.wikipedia.org/" #for simple wikipedia
BASE_WIKIPEDIA_URL = "https://en.wikipedia.org/" #for regular wikipedia

# %%
class Article:
    def __init__(self, title: str):
        self.title, self.url_title = self.__check_title(title)
        self.url = self.__build_url()
        self.soup = self.__get_page_soup(self.url)

    def __check_title(self, title: str) -> str:
        valid_page_names = wikipedia.search(title, results=3)
        if title in valid_page_names:
            return title, title.replace(" ", "_")
        else:
            raise Exception(f"I could not find that exact page, is this what you were looking for? {valid_page_names}")

    def __build_url(self) -> str:
        return BASE_WIKIPEDIA_URL + "wiki/" + self.url_title
        
    def __get_page_soup(self, url: str) -> BeautifulSoup:
        page = requests.get(url)
        soup = BeautifulSoup(page.content, "html.parser")
        return soup

    def what_links_here(self, num_of_links_start_idx: int=0, num_of_links_end_idx: int=5) -> List[str]:
        """
        Navigates to the 'What Links Here' section of your Article and gets all the article names. Does not get redirects.
        """
        links_list = []
        title = self.title.replace(" ", "+").replace("'", "&")
        what_links_here_url = f'{BASE_WIKIPEDIA_URL}w/index.php?title=Special:WhatLinksHere/{title}&namespace=0&hideredirs=0&limit=500'
        what_links_here_page_soup = self.__get_page_soup(what_links_here_url)
        soup_obj = what_links_here_page_soup.find(id="mw-whatlinkshere-list")
        for li in soup_obj.find_all("li")[num_of_links_start_idx:num_of_links_end_idx]:
            # if you find a redirect link skip it, but it will capture all the sub-links under the redirect
            if li.find("a", attrs={"class": "mw-redirect"}):
                continue
            links_list.append(li.find_all("a")[0].text)
        return links_list

    def categories(self) -> List[str]:
        """
        Parses HTML with BS4 to get all categories on the page.
        """
        catlinks = self.soup.find("div", attrs={"id": "mw-normal-catlinks"}).find_all("li")
        return [category.text for category in catlinks]

    def navbox_hierarchy(self) -> list:
        """
        Get all categories in the navbox section that have the V-T-E links to their left.
        """
        navbox_hierarchy = []
        navbox_titles = self.soup.findAll("th", attrs = {"class", "navbox-title"})
        if len(navbox_titles) == 0 :
            print(f"{self.title} page doesn't have a navbox hierarchy to scrape!")
            return []
        else:
            for navbox_title in navbox_titles:
                if len(navbox_title.findAll("div", attrs = {"class", "navbar plainlinks hlist navbar-mini"})) == 0:
                    continue

                navbox_category_item = navbox_title.findAll("div")[1].text
                navbox_hierarchy.append(navbox_category_item)
        return navbox_hierarchy

    def html_near_link(self, root_title: str) -> List[str]:
        """
        Gets html from Article object where root_title is the name of the article.
        """
        #idea while len of html content is < n characters, start with text that has element where the connection is grab one element above then one below.
        html = []
        a_tags = self.soup.find_all("a", {"title": root_title})
        for idx in range(len(a_tags)):
            #todo: check if parent.name is b or i tag and account for that information somehow
            if a_tags[idx].parent.name == "p":
                soup = a_tags[idx].parent
                html.append(str(soup))
        return html

    def examples_near_link(self, root_title: str):
        """
        Gets examples from Article object where root_title is the name of the article that is usually the core subject user is interested in understanding better.
        """
        data = []
        a_tags = self.soup.find_all("a", {"title": root_title})
        for idx in range(len(a_tags)):
            #todo: check if parent.name is b or i tag and account for that information somehow
            if a_tags[idx].parent.name == "p":
                soup = a_tags[idx].parent
                #todo: account for alt text when there are images and spans.  Idea: remove all span/img tags prior to analyzing
                print(soup)
                text_example = " ".join(soup.stripped_strings)
                if len(text_example) > 500:
                    split_text = text_example.split(".")
                    location = None
                    for sen in split_text:
                        if a_tags[idx].text in sen:
                            location = split_text.index(sen)
                            break
                    if location is None:
                        print("sentence not found!!! On tag", a_tags[idx], " with title: ", root_title)
                    data.append('.'.join(split_text[min(abs(location - 2), 0): min(len(split_text), location + 2)]))
                else:
                    # print('the length of your examples is ', len(text_example), ' characters!')    
                    data.append(text_example)
        return data

# %%
class ArticleConnections:
    def __init__(self, root_article_title: str):
        self.root_article = Article(root_article_title)
        print(f'found {len(self.root_article.what_links_here(0, 500))} related links to scan!')


    def __write_to_file(self, content: dict, path: str) -> None:
        """
        Use when you want to save outputs to a file instead of running code again.
        """
        with open(path, mode="w") as f:
            json.dump(content, f)
        print(f"writing your data to {path}")

    def get_data(self, start_idx: int, end_idx: int) -> dict:
        """
        Loops through desired number of connections based on Article.what_links_here() and gets categories and navbox information from a_tags[idx] page.
        """
        url_title = self.root_article.url_title

        related_links = self.root_article.what_links_here(start_idx, end_idx)
        print(f'found {len(related_links)} related links to scan!')
        data = {}
        for title in related_links:
            page = Article(title)
            data[title] = {
                "categories": page.categories(),
                "navbox": page.navbox_hierarchy(),
                "examples": page.html_near_link(self.root_article.title)
                }
        self.__write_to_file(data, f'outputs/get_data_{url_title}_{start_idx}-{end_idx}.json')
        return data

    def analyze_categories(self, data: dict) -> dict:
        """
        Parces data from get_data to see analytics of categories and navbox data
        returns dict -> list -> tuple
        """
        navbox_analysis = {}
        category_analysis = {}
        for page in data:
            for category in data[page]["categories"]:
                if category not in category_analysis:
                    category_analysis[category] = {"count": 1, "pages": {}}
                    category_analysis[category]["pages"][page] = data[page]["examples"]
                else:
                    category_analysis[category]["count"] += 1
                    category_analysis[category]["pages"][page] = data[page]["examples"]
            for navbox in data[page]["navbox"]:
                if navbox not in navbox_analysis:
                    navbox_analysis[navbox] = {"count": 1, "pages": {}}
                    navbox_analysis[navbox]["pages"][page] = data[page]["examples"]
                else:
                    navbox_analysis[navbox]["count"] += 1
                    navbox_analysis[navbox]["pages"][page] = data[page]["examples"]
        return {
            "category": sorted(category_analysis.items(), key=lambda x:x[1]["count"], reverse=True),
            "navbox": sorted(navbox_analysis.items(), key=lambda x:x[1]["count"], reverse=True)
        }

# %%
root = Article("Imaginary number")
links = root.what_links_here(0,5)
links
# Out:
# ['Complex analysis',
#  'Complex number',
#  'Control theory',
#  'Cauchy–Riemann equations',
#  'Definition']

# %%
from IPython.core.display import display, HTML
# Out:
# C:\Users\calep\AppData\Local\Temp\ipykernel_7236\2058709175.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
connection1 = Article("Complex analysis")
connection1.html_near_link(root.title)
# Out:
# [<p>For any complex function, the values <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle z}" xmlns="http://www.w3.org/1998/Math/MathML">
#  <semantics>
#  <mrow class="MJX-TeXAtom-ORD">
#  <mstyle displaystyle="true" scriptlevel="0">
#  <mi>z</mi>
#  </mstyle>
#  </mrow>
#  <annotation encoding="application/x-tex">{\displaystyle z}</annotation>
#  </semantics>
#  </math></span><img alt="z" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/bf368e72c009decd9b6686ee84a375632e11de98" style="vertical-align: -0.338ex; width:1.088ex; height:1.676ex;"/></span> from the domain and their images <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle f(z)}" xmlns="http://www.w3.org/1998/Math/MathML">
#  <semantics>
#  <mrow class="MJX-TeXAtom-ORD">
#  <mstyle displaystyle="true" scriptlevel="0">
#  <mi>f</mi>
#  <mo stretchy="false">(</mo>
#  <mi>z</mi>
#  <mo stretchy="false">)</mo>
#  </mstyle>
#  </mrow>
#  <annotation encoding="application/x-tex">{\displaystyle f(z)}</annotation>
#  </semantics>
#  </math></span><img alt="f(z)" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d8dd568d570b390c337c0a911f0a1c5c214e8240" style="vertical-align: -0.838ex; width:4.176ex; height:2.843ex;"/></span> in the range may be separated into <a href="/wiki/Real_number" title="Real number">real</a> and <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> parts:
#  </p>]

# %%
connection2 = Article("Complex number")
for html in connection2.html_near_link(root.title):
    display(HTML(str(html)))
# Out:
# <p>In <a href="/wiki/Mathematics" title="Mathematics">mathematics</a>, a <b>complex number</b> is an element of a <a class="mw-redirect" href="/wiki/Number_system" title="Number system">number system</a> that extends the <a href="/wiki/Real_number" title="Real number">real numbers</a> with a specific element denoted <span class="texhtml mvar" style="font-style:italic;">i</span>, called the <a href="/wiki/Imaginary_unit" title="Imaginary unit">imaginary unit</a> and satisfying the <a href="/wiki/Equation" title="Equation">equation</a> <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle i^{2}=-1}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <msup>
# <mi>i</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mn>2</mn>
# </mrow>
# </msup>
# <mo>=</mo>
# <mo>−<!-- − --></mo>
# <mn>1</mn>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle i^{2}=-1}</annotation>
# </semantics>
# </math></span><img alt="{\displaystyle i^{2}=-1}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/88e98a401d352e5037d5043028e2d7f449e83fa6" style="vertical-align: -0.505ex; width:7.926ex; height:2.843ex;"/></span>; every complex number can be expressed in the form <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle a+bi}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mi>a</mi>
# <mo>+</mo>
# <mi>b</mi>
# <mi>i</mi>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle a+bi}</annotation>
# </semantics>
# </math></span><img alt="a + bi" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/a92f853c2c9235c06be640b91b7c75e2a907cbda" style="vertical-align: -0.505ex; width:5.87ex; height:2.343ex;"/></span>, where <span class="texhtml mvar" style="font-style:italic;">a</span> and <span class="texhtml mvar" style="font-style:italic;">b</span> are real numbers. Because no real number satisfies the above equation, <span class="texhtml mvar" style="font-style:italic;">i</span> was called an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a> by <a href="/wiki/Ren%C3%A9_Descartes" title="René Descartes">René Descartes</a>. For the complex number <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle a+bi}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mi>a</mi>
# <mo>+</mo>
# <mi>b</mi>
# <mi>i</mi>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle a+bi}</annotation>
# </semantics>
# </math></span><img alt="a+bi" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/a92f853c2c9235c06be640b91b7c75e2a907cbda" style="vertical-align: -0.505ex; width:5.87ex; height:2.343ex;"/></span>, <span class="texhtml mvar" style="font-style:italic;">a</span> is called the <b><style data-mw-deduplicate="TemplateStyles:r1023754711">.mw-parser-output .vanchor>:target~.vanchor-text{background-color:#b1d2ff}</style><span class="vanchor"><span id="real_part"></span><span class="vanchor-text">real part</span></span></b>, and <span class="texhtml mvar" style="font-style:italic;">b</span> is called the <b><link href="mw-data:TemplateStyles:r1023754711" rel="mw-deduplicated-inline-style"/><span class="vanchor"><span id="imaginary_part"></span><span class="vanchor-text">imaginary part</span></span></b>. The set of complex numbers is denoted by either of the symbols <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle \mathbb {C} }" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mrow class="MJX-TeXAtom-ORD">
# <mi mathvariant="double-struck">C</mi>
# </mrow>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle \mathbb {C} }</annotation>
# </semantics>
# </math></span><img alt="\mathbb {C} " aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/f9add4085095b9b6d28d045fd9c92c2c09f549a7" style="vertical-align: -0.338ex; width:1.678ex; height:2.176ex;"/></span> or <span class="texhtml"><b>C</b></span>. Despite the historical nomenclature "imaginary", complex numbers are regarded in the <a href="/wiki/Mathematical_sciences" title="Mathematical sciences">mathematical sciences</a> as just as "real" as the real numbers and are fundamental in many aspects of the scientific description of the natural world.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup><sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[a]</a></sup>
# </p>
# <p>A real number <span class="texhtml mvar" style="font-style:italic;">a</span> can be regarded as a complex number <span class="texhtml"><i>a</i> + 0<i>i</i></span>, whose imaginary part is 0. A purely <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a> <span class="texhtml"><i>bi</i></span> is a complex number <span class="texhtml">0 + <i>bi</i></span>, whose real part is zero. As with polynomials, it is common to write <span class="texhtml mvar" style="font-style:italic;">a</span> for <span class="texhtml"><i>a</i> + 0<i>i</i></span> and <span class="texhtml"><i>bi</i></span> for <span class="texhtml">0 + <i>bi</i></span>. Moreover, when the imaginary part is negative, that is, <span class="texhtml"><i>b</i> = −<i>|b|</i> &lt; 0</span>, it is common to write <span class="texhtml"><i>a</i> − <i>|b|i</i></span> instead of <span class="texhtml"><i>a</i> + (−<i>|b|</i>)<i>i</i></span>; for example, for <span class="texhtml"><i>b</i> = −4</span>, <span class="texhtml">3 − 4<i>i</i></span> can be written instead of <span class="texhtml">3 + (−4)<i>i</i></span>.
# </p>

# %%
from IPython.core.display import display, HTML
display(HTML(
    """
    <p>For any complex function, the values <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle z}" xmlns="http://www.w3.org/1998/Math/MathML">
<semantics>
<mrow class="MJX-TeXAtom-ORD">
<mstyle displaystyle="true" scriptlevel="0">
<mi>z</mi>
</mstyle>
</mrow>
<annotation encoding="application/x-tex">{\displaystyle z}</annotation>
</semantics>
</math></span><img alt="z" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/bf368e72c009decd9b6686ee84a375632e11de98" style="vertical-align: -0.338ex; width:1.088ex; height:1.676ex;"/></span> from the domain and their images <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle f(z)}" xmlns="http://www.w3.org/1998/Math/MathML">
<semantics>
<mrow class="MJX-TeXAtom-ORD">
<mstyle displaystyle="true" scriptlevel="0">
<mi>f</mi>
<mo stretchy="false">(</mo>
<mi>z</mi>
<mo stretchy="false">)</mo>
</mstyle>
</mrow>
<annotation encoding="application/x-tex">{\displaystyle f(z)}</annotation>
</semantics>
</math></span><img alt="f(z)" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d8dd568d570b390c337c0a911f0a1c5c214e8240" style="vertical-align: -0.838ex; width:4.176ex; height:2.843ex;"/></span> in the range may be separated into <a href="/wiki/Real_number" title="Real number">real</a> and <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> parts:
</p>
    """
))
# Out:
# C:\Users\calep\AppData\Local\Temp\ipykernel_7236\1413645851.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
#     <p>For any complex function, the values <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle z}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mi>z</mi>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle z}</annotation>
# </semantics>
# </math></span><img alt="z" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/bf368e72c009decd9b6686ee84a375632e11de98" style="vertical-align: -0.338ex; width:1.088ex; height:1.676ex;"/></span> from the domain and their images <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle f(z)}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mi>f</mi>
# <mo stretchy="false">(</mo>
# <mi>z</mi>
# <mo stretchy="false">)</mo>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle f(z)}</annotation>
# </semantics>
# </math></span><img alt="f(z)" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d8dd568d570b390c337c0a911f0a1c5c214e8240" style="vertical-align: -0.838ex; width:4.176ex; height:2.843ex;"/></span> in the range may be separated into <a href="/wiki/Real_number" title="Real number">real</a> and <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> parts:
# </p>

# %%
root.examples_near_link("Imaginary number")

# %%
connections = ArticleConnections("Imaginary number")
# Out:
# found 223 related links to scan!

# %%
data = connections.get_data(0,16)
# Out:
# found 15 related links to scan!
# Physical quantity page doesn't have a navbox hierarchy to scrape!
# writing your data to outputs/get_data_Imaginary_number_0-16.json

# %%
data

analyzed_data = connections.analyze_categories(data)
analyzed_data
# Out:
# {'category': [('Complex analysis',
#    {'count': 2,
#     'pages': {'Complex analysis': ['<p>For any complex function, the values <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle z}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>z</mi>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle z}</annotation>\n</semantics>\n</math></span><img alt="z" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/bf368e72c009decd9b6686ee84a375632e11de98" style="vertical-align: -0.338ex; width:1.088ex; height:1.676ex;"/></span> from the domain and their images <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle f(z)}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>f</mi>\n<mo stretchy="false">(</mo>\n<mi>z</mi>\n<mo stretchy="false">)</mo>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle f(z)}</annotation>\n</semantics>\n</math></span><img alt="f(z)" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d8dd568d570b390c337c0a911f0a1c5c214e8240" style="vertical-align: -0.838ex; width:4.176ex; height:2.843ex;"/></span> in the range may be separated into <a href="/wiki/Real_number" title="Real number">real</a> and <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> parts:\n</p>'],
#      'Cauchy–Riemann equations': []}}),
#   ('Complex numbers',
#    {'count': 2,
#     'pages': {'Complex number': ['<p>In <a href="/wiki/Mathematics" title="Mathematics">mathematics</a>, a <b>complex number</b> is an element of a <a class="mw-redirect" href="/wiki/Number_system" title="Number system">number system</a> that extends the <a href="/wiki/Real_number" title="Real number">real numbers</a> with a specific element denoted <span class="texhtml mvar" style="font-style:italic;">i</span>, called the <a href="/wiki/Imaginary_unit" title="Imaginary unit">imaginary unit</a> and satisfying the <a href="/wiki/Equation" title="Equation">equation</a> <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle i^{2}=-1}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<msup>\n<mi>i</mi>\n<mrow class="MJX-TeXAtom-ORD">\n<mn>2</mn>\n</mrow>\n</msup>\n<mo>=</mo>\n<mo>−<!-- − --></mo>\n<mn>1</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle i^{2}=-1}</annotation>\n</semantics>\n</math></span><img alt="{\\displaystyle i^{2}=-1}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/88e98a401d352e5037d5043028e2d7f449e83fa6" style="vertical-align: -0.505ex; width:7.926ex; height:2.843ex;"/></span>; every complex number can be expressed in the form <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle a+bi}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>a</mi>\n<mo>+</mo>\n<mi>b</mi>\n<mi>i</mi>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle a+bi}</annotation>\n</semantics>\n</math></span><img alt="a + bi" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/a92f853c2c9235c06be640b91b7c75e2a907cbda" style="vertical-align: -0.505ex; width:5.87ex; height:2.343ex;"/></span>, where <span class="texhtml mvar" style="font-style:italic;">a</span> and <span class="texhtml mvar" style="font-style:italic;">b</span> are real numbers. Because no real number satisfies the above equation, <span class="texhtml mvar" style="font-style:italic;">i</span> was called an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a> by <a href="/wiki/Ren%C3%A9_Descartes" title="René Descartes">René Descartes</a>. For the complex number <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle a+bi}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>a</mi>\n<mo>+</mo>\n<mi>b</mi>\n<mi>i</mi>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle a+bi}</annotation>\n</semantics>\n</math></span><img alt="a+bi" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/a92f853c2c9235c06be640b91b7c75e2a907cbda" style="vertical-align: -0.505ex; width:5.87ex; height:2.343ex;"/></span>, <span class="texhtml mvar" style="font-style:italic;">a</span> is called the <b><style data-mw-deduplicate="TemplateStyles:r1023754711">.mw-parser-output .vanchor>:target~.vanchor-text{background-color:#b1d2ff}</style><span class="vanchor"><span id="real_part"></span><span class="vanchor-text">real part</span></span></b>, and <span class="texhtml mvar" style="font-style:italic;">b</span> is called the <b><link href="mw-data:TemplateStyles:r1023754711" rel="mw-deduplicated-inline-style"/><span class="vanchor"><span id="imaginary_part"></span><span class="vanchor-text">imaginary part</span></span></b>. The set of complex numbers is denoted by either of the sym ...
#       '<p>A real number <span class="texhtml mvar" style="font-style:italic;">a</span> can be regarded as a complex number <span class="texhtml"><i>a</i> + 0<i>i</i></span>, whose imaginary part is 0. A purely <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a> <span class="texhtml"><i>bi</i></span> is a complex number <span class="texhtml">0 + <i>bi</i></span>, whose real part is zero. As with polynomials, it is common to write <span class="texhtml mvar" style="font-style:italic;">a</span> for <span class="texhtml"><i>a</i> + 0<i>i</i></span> and <span class="texhtml"><i>bi</i></span> for <span class="texhtml">0 + <i>bi</i></span>. Moreover, when the imaginary part is negative, that is, <span class="texhtml"><i>b</i> = −<i>|b|</i> &lt; 0</span>, it is common to write <span class="texhtml"><i>a</i> − <i>|b|i</i></span> instead of <span class="texhtml"><i>a</i> + (−<i>|b|</i>)<i>i</i></span>; for example, for <span class="texhtml"><i>b</i> = −4</span>, <span class="texhtml">3 − 4<i>i</i></span> can be written instead of <span class="texhtml">3 + (−4)<i>i</i></span>.\n</p>'],
#      'Imaginary number': []}}),
#   ('Composition algebras',
#    {'count': 1,
#     'pages': {'Complex number': ['<p>In <a href="/wiki/Mathematics" title="Mathematics">mathematics</a>, a <b>complex number</b> is an element of a <a class="mw-redirect" href="/wiki/Number_system" title="Number system">number system</a> that extends the <a href="/wiki/Real_number" title="Real number">real numbers</a> with a specific element denoted <span class="texhtml mvar" style="font-style:italic;">i</span>, called the <a href="/wiki/Imaginary_unit" title="Imaginary unit">imaginary unit</a> and satisfying the <a href="/wiki/Equation" title="Equation">equation</a> <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle i^{2}=-1}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<msup>\n<mi>i</mi>\n<mrow class="MJX-TeXAtom-ORD">\n<mn>2</mn>\n</mrow>\n</msup>\n<mo>=</mo>\n<mo>−<!-- − --></mo>\n<mn>1</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle i^{2}=-1}</annotation>\n</semantics>\n</math></span><img alt="{\\displaystyle i^{2}=-1}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/88e98a401d352e5037d5043028e2d7f449e83fa6" style="vertical-align: -0.505ex; width:7.926ex; height:2.843ex;"/></span>; every complex number can be expressed in the form <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle a+bi}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>a</mi>\n<mo>+</mo>\n<mi>b</mi>\n<mi>i</mi>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle a+bi}</annotation>\n</semantics>\n</math></span><img alt="a + bi" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/a92f853c2c9235c06be640b91b7c75e2a907cbda" style="vertical-align: -0.505ex; width:5.87ex; height:2.343ex;"/></span>, where <span class="texhtml mvar" style="font-style:italic;">a</span> and <span class="texhtml mvar" style="font-style:italic;">b</span> are real numbers. Because no real number satisfies the above equation, <span class="texhtml mvar" style="font-style:italic;">i</span> was called an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a> by <a href="/wiki/Ren%C3%A9_Descartes" title="René Descartes">René Descartes</a>. For the complex number <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle a+bi}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>a</mi>\n<mo>+</mo>\n<mi>b</mi>\n<mi>i</mi>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle a+bi}</annotation>\n</semantics>\n</math></span><img alt="a+bi" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/a92f853c2c9235c06be640b91b7c75e2a907cbda" style="vertical-align: -0.505ex; width:5.87ex; height:2.343ex;"/></span>, <span class="texhtml mvar" style="font-style:italic;">a</span> is called the <b><style data-mw-deduplicate="TemplateStyles:r1023754711">.mw-parser-output .vanchor>:target~.vanchor-text{background-color:#b1d2ff}</style><span class="vanchor"><span id="real_part"></span><span class="vanchor-text">real part</span></span></b>, and <span class="texhtml mvar" style="font-style:italic;">b</span> is called the <b><link href="mw-data:TemplateStyles:r1023754711" rel="mw-deduplicated-inline-style"/><span class="vanchor"><span id="imaginary_part"></span><span class="vanchor-text">imaginary part</span></span></b>. The set of complex numbers is denoted by either of the sym ...
#       '<p>A real number <span class="texhtml mvar" style="font-style:italic;">a</span> can be regarded as a complex number <span class="texhtml"><i>a</i> + 0<i>i</i></span>, whose imaginary part is 0. A purely <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a> <span class="texhtml"><i>bi</i></span> is a complex number <span class="texhtml">0 + <i>bi</i></span>, whose real part is zero. As with polynomials, it is common to write <span class="texhtml mvar" style="font-style:italic;">a</span> for <span class="texhtml"><i>a</i> + 0<i>i</i></span> and <span class="texhtml"><i>bi</i></span> for <span class="texhtml">0 + <i>bi</i></span>. Moreover, when the imaginary part is negative, that is, <span class="texhtml"><i>b</i> = −<i>|b|</i> &lt; 0</span>, it is common to write <span class="texhtml"><i>a</i> − <i>|b|i</i></span> instead of <span class="texhtml"><i>a</i> + (−<i>|b|</i>)<i>i</i></span>; for example, for <span class="texhtml"><i>b</i> = −4</span>, <span class="texhtml">3 − 4<i>i</i></span> can be written instead of <span class="texhtml">3 + (−4)<i>i</i></span>.\n</p>']}}),
#   ('Control theory',
#    {'count': 1,
#     'pages': {'Control theory': ['<p>which has a pole in <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle z=0.5}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>z</mi>\n<mo>=</mo>\n<mn>0.5</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle z=0.5}</annotation>\n</semantics>\n</math></span><img alt="z=0.5" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d9267ea9749ae11b3cde9c735c21f2507de379f3" style="vertical-align: -0.338ex; width:7.158ex; height:2.176ex;"/></span> (zero <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary part</a>). This system is BIBO (asymptotically) stable since the pole is <i>inside</i> the unit circle.\n</p>']}}),
#   ('Control engineering',
#    {'count': 1,
#     'pages': {'Control theory': ['<p>which has a pole in <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle z=0.5}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>z</mi>\n<mo>=</mo>\n<mn>0.5</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle z=0.5}</annotation>\n</semantics>\n</math></span><img alt="z=0.5" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d9267ea9749ae11b3cde9c735c21f2507de379f3" style="vertical-align: -0.338ex; width:7.158ex; height:2.176ex;"/></span> (zero <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary part</a>). This system is BIBO (asymptotically) stable since the pole is <i>inside</i> the unit circle.\n</p>']}}),
#   ('Computer engineering',
#    {'count': 1,
#     'pages': {'Control theory': ['<p>which has a pole in <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle z=0.5}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>z</mi>\n<mo>=</mo>\n<mn>0.5</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle z=0.5}</annotation>\n</semantics>\n</math></span><img alt="z=0.5" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d9267ea9749ae11b3cde9c735c21f2507de379f3" style="vertical-align: -0.338ex; width:7.158ex; height:2.176ex;"/></span> (zero <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary part</a>). This system is BIBO (asymptotically) stable since the pole is <i>inside</i> the unit circle.\n</p>']}}),
#   ('Cybernetics',
#    {'count': 1,
#     'pages': {'Control theory': ['<p>which has a pole in <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle z=0.5}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>z</mi>\n<mo>=</mo>\n<mn>0.5</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle z=0.5}</annotation>\n</semantics>\n</math></span><img alt="z=0.5" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d9267ea9749ae11b3cde9c735c21f2507de379f3" style="vertical-align: -0.338ex; width:7.158ex; height:2.176ex;"/></span> (zero <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary part</a>). This system is BIBO (asymptotically) stable since the pole is <i>inside</i> the unit circle.\n</p>']}}),
#   ('Partial differential equations',
#    {'count': 1, 'pages': {'Cauchy–Riemann equations': []}}),
#   ('Harmonic functions',
#    {'count': 1, 'pages': {'Cauchy–Riemann equations': []}}),
#   ('Bernhard Riemann',
#    {'count': 1, 'pages': {'Cauchy–Riemann equations': []}}),
#   ('Augustin-Louis Cauchy',
#    {'count': 1, 'pages': {'Cauchy–Riemann equations': []}}),
#   ('Definition',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Philosophical logic',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Philosophy of language',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Semantics',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Linguistics terminology',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Mathematical terminology',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Concepts in logic',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Lexicography',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Meaning (philosophy of language)',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Theorems in complex analysis',
#    {'count': 1,
#     'pages': {"Euler's formula": ['<p>In <a href="/wiki/Electrical_engineering" title="Electrical engineering">electrical engineering</a>, <a href="/wiki/Signal_processing" title="Signal processing">signal processing</a>, and similar fields, signals that vary periodically over time are often described as a combination of sinusoidal functions (see <a href="/wiki/Fourier_analysis" title="Fourier analysis">Fourier analysis</a>), and these are more conveniently expressed as the sum of exponential functions with <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> exponents, using Euler\'s formula. Also, <a class="mw-redirect" href="/wiki/Phasor_analysis" title="Phasor analysis">phasor analysis</a> of circuits can include Euler\'s formula to represent the impedance of a capacitor or an inductor.\n</p>']}}),
#   ('Analysis',
#    {'count': 1,
#     'pages': {"Euler's formula": ['<p>In <a href="/wiki/Electrical_engineering" title="Electrical engineering">electrical engineering</a>, <a href="/wiki/Signal_processing" title="Signal processing">signal processing</a>, and similar fields, signals that vary periodically over time are often described as a combination of sinusoidal functions (see <a href="/wiki/Fourier_analysis" title="Fourier analysis">Fourier analysis</a>), and these are more conveniently expressed as the sum of exponential functions with <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> exponents, using Euler\'s formula. Also, <a class="mw-redirect" href="/wiki/Phasor_analysis" title="Phasor analysis">phasor analysis</a> of circuits can include Euler\'s formula to represent the impedance of a capacitor or an inductor.\n</p>']}}),
#   ('E (mathematical constant)',
#    {'count': 1,
#     'pages': {"Euler's formula": ['<p>In <a href="/wiki/Electrical_engineering" title="Electrical engineering">electrical engineering</a>, <a href="/wiki/Signal_processing" title="Signal processing">signal processing</a>, and similar fields, signals that vary periodically over time are often described as a combination of sinusoidal functions (see <a href="/wiki/Fourier_analysis" title="Fourier analysis">Fourier analysis</a>), and these are more conveniently expressed as the sum of exponential functions with <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> exponents, using Euler\'s formula. Also, <a class="mw-redirect" href="/wiki/Phasor_analysis" title="Phasor analysis">phasor analysis</a> of circuits can include Euler\'s formula to represent the impedance of a capacitor or an inductor.\n</p>']}}),
#   ('Trigonometry',
#    {'count': 1,
#     'pages': {"Euler's formula": ['<p>In <a href="/wiki/Electrical_engineering" title="Electrical engineering">electrical engineering</a>, <a href="/wiki/Signal_processing" title="Signal processing">signal processing</a>, and similar fields, signals that vary periodically over time are often described as a combination of sinusoidal functions (see <a href="/wiki/Fourier_analysis" title="Fourier analysis">Fourier analysis</a>), and these are more conveniently expressed as the sum of exponential functions with <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> exponents, using Euler\'s formula. Also, <a class="mw-redirect" href="/wiki/Phasor_analysis" title="Phasor analysis">phasor analysis</a> of circuits can include Euler\'s formula to represent the impedance of a capacitor or an inductor.\n</p>']}}),
#   ('Leonhard Euler',
#    {'count': 1,
#     'pages': {"Euler's formula": ['<p>In <a href="/wiki/Electrical_engineering" title="Electrical engineering">electrical engineering</a>, <a href="/wiki/Signal_processing" title="Signal processing">signal processing</a>, and similar fields, signals that vary periodically over time are often described as a combination of sinusoidal functions (see <a href="/wiki/Fourier_analysis" title="Fourier analysis">Fourier analysis</a>), and these are more conveniently expressed as the sum of exponential functions with <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> exponents, using Euler\'s formula. Also, <a class="mw-redirect" href="/wiki/Phasor_analysis" title="Phasor analysis">phasor analysis</a> of circuits can include Euler\'s formula to represent the impedance of a capacitor or an inductor.\n</p>']}}),
#   ('Elementary algebra',
#    {'count': 1,
#     'pages': {'Elementary algebra': ['<p>All quadratic equations have exactly two solutions in <a class="mw-redirect" href="/wiki/Complex_numbers" title="Complex numbers">complex numbers</a> (but they may be equal to each other), a category that includes <a href="/wiki/Real_number" title="Real number">real numbers</a>, <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary numbers</a>, and sums of real and imaginary numbers. Complex numbers first arise in the teaching of quadratic equations and the quadratic formula. For example, the quadratic equation\n</p>']}}),
#   ('Algebra',
#    {'count': 1,
#     'pages': {'Elementary algebra': ['<p>All quadratic equations have exactly two solutions in <a class="mw-redirect" href="/wiki/Complex_numbers" title="Complex numbers">complex numbers</a> (but they may be equal to each other), a category that includes <a href="/wiki/Real_number" title="Real number">real numbers</a>, <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary numbers</a>, and sums of real and imaginary numbers. Complex numbers first arise in the teaching of quadratic equations and the quadratic formula. For example, the quadratic equation\n</p>']}}),
#   ('Means', {'count': 1, 'pages': {'Geometric mean': []}}),
#   ('Non-Newtonian calculus', {'count': 1, 'pages': {'Geometric mean': []}}),
#   ('1501 births',
#    {'count': 1,
#     'pages': {'Gerolamo Cardano': ['<p>Today, he is well known for his achievements in <a href="/wiki/Algebra" title="Algebra">algebra</a>. In his 1545 book <i><a href="/wiki/Ars_Magna_(Cardano_book)" title="Ars Magna (Cardano book)">Ars Magna</a></i>, he made the first systematic use of <a class="mw-redirect" href="/wiki/Negative_numbers" title="Negative numbers">negative numbers</a> in Europe, published with attribution the solutions of other mathematicians for the <a href="/wiki/Cubic_equation" title="Cubic equation">cubic</a> and <a href="/wiki/Quartic_equation" title="Quartic equation">quartic equations</a>, and acknowledged the existence of <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary numbers</a>.\n</p>',
#       '<p>Gerolamo Cardano was the first European mathematician to make systematic use of negative numbers.<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[14]</a></sup> He published with attribution the solution of <a href="/wiki/Scipione_del_Ferro" title="Scipione del Ferro">Scipione del Ferro</a> to the <a href="/wiki/Cubic_equation" title="Cubic equation">cubic equation</a> and the solution of Cardano\'s student <a href="/wiki/Lodovico_Ferrari" title="Lodovico Ferrari">Lodovico Ferrari</a> to the <a href="/wiki/Quartic_equation" title="Quartic equation">quartic equation</a> in his 1545 book <i><a href="/wiki/Ars_Magna_(Cardano_book)" title="Ars Magna (Cardano book)">Ars Magna</a></i>, an influential work on algebra. The solution to one particular case of the cubic equation <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle ax^{3}+bx+c=0}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>a</mi>\n<msup>\n<mi>x</mi>\n<mrow class="MJX-TeXAtom-ORD">\n<mn>3</mn>\n</mrow>\n</msup>\n<mo>+</mo>\n<mi>b</mi>\n<mi>x</mi>\n<mo>+</mo>\n<mi>c</mi>\n<mo>=</mo>\n<mn>0</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle ax^{3}+bx+c=0}</annotation>\n</semantics>\n</math></span><img alt="ax^3+bx+c=0" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/31f46f92d1475384e89f74589c1078cda0a1eaca" style="vertical-align: -0.505ex; width:16.89ex; height:2.843ex;"/></span><sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup> (in modern notation) had been communicated to him in 1539 by <a href="/wiki/Niccol%C3%B2_Fontana_Tartaglia" title="Niccolò Fontana Tartaglia">Niccolò Fontana Tartaglia</a> (who later claimed that Cardano had sworn not to reveal it, and engaged Cardano in a decade-long dispute) in the form of a poem,<sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup> but del Ferro\'s solution predated Tartaglia\'s.<sup class="reference" id="cite_ref-:0_13-1"><a href="#cite_note-:0-13">[13]</a></sup> In his exposition, he acknowledged the existence of what are now called <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary numbers</a>, although he did not understand their properties, described for the first time by his Italian contemporary <a href="/wiki/Rafael_Bombelli" title="Rafael Bombelli">Rafael Bombelli</a>. In <i>Opus novum de proportionibus</i> he introduced the <a href="/wiki/Binomial_coefficient" title="Binomial coefficient">binomial coefficients</a> and the <a href="/wiki/Binomial_theorem" title="Binomial theorem">binomial theorem</a>.\n</p>']}}),
#   ('1576 deaths',
#    {'count': 1,
#     'pages': {'Gerolamo Cardano': ['<p>Today, he is well known for his achievements in <a href="/wiki/Algebra" title="Algebra">algebra</a>. In his 1545 book <i><a href="/wiki/Ars_Magna_(Cardano_book)" title="Ars Magna (Cardano book)">Ars Magna</a></i>, he made the first systematic use of <a class="mw-redirect" href="/wiki/Negative_numbers" title="Negative numbers">negative numbers</a> in Europe, published with attribution the solutions of other mathematicians for the <a href="/wiki/Cubic_equation" title="Cubic equation">cubic</a> and <a href="/wiki/Quartic_equation" title="Quartic equation">quartic equations</a>, and acknowledged the existence of <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary numbers</a>.\n</p>',
#       '<p>Gerolamo Cardano was the first European mathematician to make systematic use of negative numbers.<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[14]</a></sup> He published with attribution the solution of <a href="/wiki/Scipione_del_Ferro" title="Scipione del Ferro">Scipione del Ferro</a> to the <a href="/wiki/Cubic_equation" title="Cubic equation">cubic equation</a> and the solution of Cardano\'s student <a href="/wiki/Lodovico_Ferrari" title="Lodovico Ferrari">Lodovico Ferrari</a> to the <a href="/wiki/Quartic_equation" title="Quartic equation">quartic equation</a> in his 1545 book <i><a href="/wiki/Ars_Magna_(Cardano_book)" title="Ars Magna (Cardano book)">Ars Magna</a></i>, an influential work on algebra. The solution to one particular case of the cubic equation <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle ax^{3}+bx+c=0}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>a</mi>\n<msup>\n<mi>x</mi>\n<mrow class="MJX-TeXAtom-ORD">\n<mn>3</mn>\n</mrow>\n</msup>\n<mo>+</mo>\n<mi>b</mi>\n<mi>x</mi>\n<mo>+</mo>\n<mi>c</mi>\n<mo>=</mo>\n<mn>0</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle ax^{3}+bx+c=0}</annotation>\n</semantics>\n</math></span><img alt="ax^3+bx+c=0" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/31f46f92d1475384e89f74589c1078cda0a1eaca" style="vertical-align: -0.505ex; width:16.89ex; height:2.843ex;"/></span><sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup> (in modern notation) had been communicated to him in 1539 by <a href="/wiki/Niccol%C3%B2_Fontana_Tartaglia" title="Niccolò Fontana Tartaglia">Niccolò Fontana Tartaglia</a> (who later claimed that Cardano had sworn not to reveal it, and engaged Cardano in a decade-long dispute) in the form of a poem,<sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup> but del Ferro\'s solution predated Tartaglia\'s.<sup class="reference" id="cite_ref-:0_13-1"><a href="#cite_note-:0-13">[13]</a></sup> In his exposition, he acknowledged the existence of what are now called <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary numbers</a>, although he did not understand their properties, described for the first time by his Italian contemporary <a href="/wiki/Rafael_Bombelli" title="Rafael Bombelli">Rafael Bombelli</a>. In <i>Opus novum de proportionibus</i> he introduced the <a href="/wiki/Binomial_coefficient" title="Binomial coefficient">binomial coefficients</a> and the <a href="/wiki/Binomial_theorem" title="Binomial theorem">binomial theorem</a>.\n</p>']}}),
#   ('16th-century Latin-language writers',
#    {'count': 1,
#     'pages': {'Gerolamo Cardano': ['<p>Today, he is well known for his achievements in <a href="/wiki/Algebra" title="Algebra">algebra</a>. In his 1545 book <i><a href="/wiki/Ars_Magna_(Cardano_book)" title="Ars Magna (Cardano book)">Ars Magna</a></i>, he made the first systematic use of <a class="mw-redirect" href="/wiki/Negative_numbers" title="Negative numbers">negative numbers</a> in Europe, published with attribution the solutions of other mathematicians for the <a href="/wiki/Cubic_equation" title="Cubic equation">cubic</a> and <a href="/wiki/Quartic_equation" title="Quartic equation">quartic equations</a>, and acknowledged the existence of <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary numbers</a>.\n</p>',
#       '<p>Gerolamo Cardano was the first European mathematician to make systematic use of negative numbers.<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[14]</a></sup> He published with attribution the solution of <a href="/wiki/Scipione_del_Ferro" title="Scipione del Ferro">Scipione del Ferro</a> to the <a href="/wiki/Cubic_equation" title="Cubic equation">cubic equation</a> and the solution of Cardano\'s student <a href="/wiki/Lodovico_Ferrari" title="Lodovico Ferrari">Lodovico Ferrari</a> to the <a href="/wiki/Quartic_equation" title="Quartic equation">quartic equation</a> in his 1545 book <i><a href="/wiki/Ars_Magna_(Cardano_book)" title="Ars Magna (Cardano book)">Ars Magna</a></i>, an influential work on algebra. The solution to one particular case of the cubic equation <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle ax^{3}+bx+c=0}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>a</mi>\n<msup>\n<mi>x</mi>\n<mrow class="MJX-TeXAtom-ORD">\n<mn>3</mn>\n</mrow>\n</msup>\n<mo>+</mo>\n<mi>b</mi>\n<mi>x</mi>\n<mo>+</mo>\n<mi>c</mi>\n<mo>=</mo>\n<mn>0</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle ax^{3}+bx+c=0}</annotation>\n</semantics>\n</math></span><img alt="ax^3+bx+c=0" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/31f46f92d1475384e89f74589c1078cda0a1eaca" style="vertical-align: -0.505ex; width:16.89ex; height:2.843ex;"/></span><sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup> (in modern notation) had been communicated to him in 1539 by <a href="/wiki/Niccol%C3%B2_Fontana_Tartaglia" title="Niccolò Fontana Tartaglia">Niccolò Fontana Tartaglia</a> (who later claimed that Cardano had sworn not to reveal it, and engaged Cardano in a decade-long dispute) in the form of a poem,<sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup> but del Ferro\'s solution predated Tartaglia\'s.<sup class="reference" id="cite_ref-:0_13-1"><a href="#cite_note-:0-13">[13]</a></sup> In his exposition, he acknowledged the existence of what are now called <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary numbers</a>, although he did not understand their properties, described for the first time by his Italian contemporary <a href="/wiki/Rafael_Bombelli" title="Rafael Bombelli">Rafael Bombelli</a>. In <i>Opus novum de proportionibus</i> he introduced the <a href="/wiki/Binomial_coefficient" title="Binomial coefficient">binomial coefficients</a> and the <a href="/wiki/Binomial_theorem" title="Binomial theorem">binomial theorem</a>.\n</p>']}}),
#   ('16th-century Italian mathematicians',
#    {'count': 1,
#     'pages': {'Gerolamo Cardano': ['<p>Today, he is well known for his achievements in <a href="/wiki/Algebra" title="Algebra">algebra</a>. In his 1545 book <i><a href="/wiki/Ars_Magna_(Cardano_book)" title="Ars Magna (Cardano book)">Ars Magna</a></i>, he made the first systematic use of <a class="mw-redirect" href="/wiki/Negative_numbers" title="Negative numbers">negative numbers</a> in Europe, published with attribution the solutions of other mathematicians for the <a href="/wiki/Cubic_equation" title="Cubic equation">cubic</a> and <a href="/wiki/Quartic_equation" title="Quartic equation">quartic equations</a>, and acknowledged the existence of <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary numbers</a>.\n</p>',
# ...
#      'Imaginary number': []}}),
#   ('Major topics in mathematical analysis',
#    {'count': 1,
#     'pages': {'Complex analysis': ['<p>For any complex function, the values <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle z}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>z</mi>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle z}</annotation>\n</semantics>\n</math></span><img alt="z" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/bf368e72c009decd9b6686ee84a375632e11de98" style="vertical-align: -0.338ex; width:1.088ex; height:1.676ex;"/></span> from the domain and their images <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle f(z)}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>f</mi>\n<mo stretchy="false">(</mo>\n<mi>z</mi>\n<mo stretchy="false">)</mo>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle f(z)}</annotation>\n</semantics>\n</math></span><img alt="f(z)" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d8dd568d570b390c337c0a911f0a1c5c214e8240" style="vertical-align: -0.838ex; width:4.176ex; height:2.843ex;"/></span> in the range may be separated into <a href="/wiki/Real_number" title="Real number">real</a> and <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> parts:\n</p>']}}),
#   ('Control theory',
#    {'count': 1,
#     'pages': {'Control theory': ['<p>which has a pole in <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle z=0.5}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>z</mi>\n<mo>=</mo>\n<mn>0.5</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle z=0.5}</annotation>\n</semantics>\n</math></span><img alt="z=0.5" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d9267ea9749ae11b3cde9c735c21f2507de379f3" style="vertical-align: -0.338ex; width:7.158ex; height:2.176ex;"/></span> (zero <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary part</a>). This system is BIBO (asymptotically) stable since the pole is <i>inside</i> the unit circle.\n</p>']}}),
#   ('Subfields of and cyberneticians involved in cybernetics',
#    {'count': 1,
#     'pages': {'Control theory': ['<p>which has a pole in <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle z=0.5}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>z</mi>\n<mo>=</mo>\n<mn>0.5</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle z=0.5}</annotation>\n</semantics>\n</math></span><img alt="z=0.5" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d9267ea9749ae11b3cde9c735c21f2507de379f3" style="vertical-align: -0.338ex; width:7.158ex; height:2.176ex;"/></span> (zero <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary part</a>). This system is BIBO (asymptotically) stable since the pole is <i>inside</i> the unit circle.\n</p>']}}),
#   ('Systems science',
#    {'count': 1,
#     'pages': {'Control theory': ['<p>which has a pole in <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\\displaystyle z=0.5}" xmlns="http://www.w3.org/1998/Math/MathML">\n<semantics>\n<mrow class="MJX-TeXAtom-ORD">\n<mstyle displaystyle="true" scriptlevel="0">\n<mi>z</mi>\n<mo>=</mo>\n<mn>0.5</mn>\n</mstyle>\n</mrow>\n<annotation encoding="application/x-tex">{\\displaystyle z=0.5}</annotation>\n</semantics>\n</math></span><img alt="z=0.5" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d9267ea9749ae11b3cde9c735c21f2507de379f3" style="vertical-align: -0.338ex; width:7.158ex; height:2.176ex;"/></span> (zero <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary part</a>). This system is BIBO (asymptotically) stable since the pole is <i>inside</i> the unit circle.\n</p>']}}),
#   ('Bernhard Riemann',
#    {'count': 1, 'pages': {'Cauchy–Riemann equations': []}}),
#   ('Definition',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Logic',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Aristotelian logic (syllogistic)',
#    {'count': 1,
#     'pages': {'Definition': ['<p>In mathematics, definitions are generally not used to describe existing terms, but to describe or characterize a concept.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[18]</a></sup> For naming the object of a definition mathematicians can use either a <a href="/wiki/Neologism" title="Neologism">neologism</a> (this was mainly the case in the past) or words or phrases of the common language (this is generally the case in modern mathematics). The precise meaning of a term given by a mathematical definition is often different than the English definition of the word used,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[19]</a></sup> which can lead to confusion, particularly when the meanings are close. For example a <a href="/wiki/Set_(mathematics)" title="Set (mathematics)">set</a> is not exactly the same thing in mathematics and in common language. In some case, the word used can be misleading; for example, a <a href="/wiki/Real_number" title="Real number">real number</a> has nothing more (or less) real than an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a>.  Frequently, a definition uses a phrase built with common English words, which has no meaning outside mathematics, such as <a class="mw-redirect" href="/wiki/Primitive_group" title="Primitive group">primitive group</a> or <a class="mw-redirect" href="/wiki/Irreducible_variety" title="Irreducible variety">irreducible variety</a>.\n</p>']}}),
#   ('Leonhard Euler',
#    {'count': 1,
#     'pages': {"Euler's formula": ['<p>In <a href="/wiki/Electrical_engineering" title="Electrical engineering">electrical engineering</a>, <a href="/wiki/Signal_processing" title="Signal processing">signal processing</a>, and similar fields, signals that vary periodically over time are often described as a combination of sinusoidal functions (see <a href="/wiki/Fourier_analysis" title="Fourier analysis">Fourier analysis</a>), and these are more conveniently expressed as the sum of exponential functions with <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> exponents, using Euler\'s formula. Also, <a class="mw-redirect" href="/wiki/Phasor_analysis" title="Phasor analysis">phasor analysis</a> of circuits can include Euler\'s formula to represent the impedance of a capacitor or an inductor.\n</p>']}}),
#   ('Algebra',
#    {'count': 1,
#     'pages': {'Elementary algebra': ['<p>All quadratic equations have exactly two solutions in <a class="mw-redirect" href="/wiki/Complex_numbers" title="Complex numbers">complex numbers</a> (but they may be equal to each other), a category that includes <a href="/wiki/Real_number" title="Real number">real numbers</a>, <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary numbers</a>, and sums of real and imaginary numbers. Complex numbers first arise in the teaching of quadratic equations and the quadratic formula. For example, the quadratic equation\n</p>']}}),
#   ('Statistics', {'count': 1, 'pages': {'Geometric mean': []}}),
#   ('Indian mathematics',
#    {'count': 1,
#     'pages': {'History of mathematics': ['<p>In Italy, during the first half of the 16th century, <a href="/wiki/Scipione_del_Ferro" title="Scipione del Ferro">Scipione del Ferro</a> and <a href="/wiki/Niccol%C3%B2_Fontana_Tartaglia" title="Niccolò Fontana Tartaglia">Niccolò Fontana Tartaglia</a> discovered solutions for <a href="/wiki/Cubic_equation" title="Cubic equation">cubic equations</a>. <a href="/wiki/Gerolamo_Cardano" title="Gerolamo Cardano">Gerolamo Cardano</a> published them in his 1545 book <i><a class="mw-redirect" href="/wiki/Ars_Magna_(Gerolamo_Cardano)" title="Ars Magna (Gerolamo Cardano)">Ars Magna</a></i>, together with a solution for the <a href="/wiki/Quartic_equation" title="Quartic equation">quartic equations</a>, discovered by his student <a href="/wiki/Lodovico_Ferrari" title="Lodovico Ferrari">Lodovico Ferrari</a>. In 1572 <a href="/wiki/Rafael_Bombelli" title="Rafael Bombelli">Rafael Bombelli</a> published his <i>L\'Algebra</i> in which he showed how to deal with the <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary quantities</a> that could appear in Cardano\'s formula for solving cubic equations.\n</p>']}}),
#   ('Mathematics in the medieval Islamic world',
#    {'count': 1,
#     'pages': {'History of mathematics': ['<p>In Italy, during the first half of the 16th century, <a href="/wiki/Scipione_del_Ferro" title="Scipione del Ferro">Scipione del Ferro</a> and <a href="/wiki/Niccol%C3%B2_Fontana_Tartaglia" title="Niccolò Fontana Tartaglia">Niccolò Fontana Tartaglia</a> discovered solutions for <a href="/wiki/Cubic_equation" title="Cubic equation">cubic equations</a>. <a href="/wiki/Gerolamo_Cardano" title="Gerolamo Cardano">Gerolamo Cardano</a> published them in his 1545 book <i><a class="mw-redirect" href="/wiki/Ars_Magna_(Gerolamo_Cardano)" title="Ars Magna (Gerolamo Cardano)">Ars Magna</a></i>, together with a solution for the <a href="/wiki/Quartic_equation" title="Quartic equation">quartic equations</a>, discovered by his student <a href="/wiki/Lodovico_Ferrari" title="Lodovico Ferrari">Lodovico Ferrari</a>. In 1572 <a href="/wiki/Rafael_Bombelli" title="Rafael Bombelli">Rafael Bombelli</a> published his <i>L\'Algebra</i> in which he showed how to deal with the <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary quantities</a> that could appear in Cardano\'s formula for solving cubic equations.\n</p>']}}),
#   ('History of science',
#    {'count': 1,
#     'pages': {'History of mathematics': ['<p>In Italy, during the first half of the 16th century, <a href="/wiki/Scipione_del_Ferro" title="Scipione del Ferro">Scipione del Ferro</a> and <a href="/wiki/Niccol%C3%B2_Fontana_Tartaglia" title="Niccolò Fontana Tartaglia">Niccolò Fontana Tartaglia</a> discovered solutions for <a href="/wiki/Cubic_equation" title="Cubic equation">cubic equations</a>. <a href="/wiki/Gerolamo_Cardano" title="Gerolamo Cardano">Gerolamo Cardano</a> published them in his 1545 book <i><a class="mw-redirect" href="/wiki/Ars_Magna_(Gerolamo_Cardano)" title="Ars Magna (Gerolamo Cardano)">Ars Magna</a></i>, together with a solution for the <a href="/wiki/Quartic_equation" title="Quartic equation">quartic equations</a>, discovered by his student <a href="/wiki/Lodovico_Ferrari" title="Lodovico Ferrari">Lodovico Ferrari</a>. In 1572 <a href="/wiki/Rafael_Bombelli" title="Rafael Bombelli">Rafael Bombelli</a> published his <i>L\'Algebra</i> in which he showed how to deal with the <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary quantities</a> that could appear in Cardano\'s formula for solving cubic equations.\n</p>']}}),
#   ('Integers', {'count': 1, 'pages': {'Integer': []}}),
#   ('Rational numbers', {'count': 1, 'pages': {'Integer': []}}),
#   ('Typography', {'count': 1, 'pages': {'Blackboard bold': []}}),
#   ('Mathematical notation, symbols, and formulas',
#    {'count': 1, 'pages': {'Blackboard bold': []}})]}

# %%
html = """"""
for category in analyzed_data["category"]:
    category_name = category[0]
    category_data = category[1]
    html += f'<h1>{category_name} has {category_data["count"]} connections!</h1>'
    for page in category_data["pages"]:
        # print('the page is', page)
        html += f'<h3>{page}</h3>'
        for example in category_data["pages"][page]:
            # print('the example is ', example)
            html += f'<p>{example}</p>'


        
    html += f'<h3></h3>'
    # print(f'the category is {category_name} and there are {category_data["count"]} connections to it!')

display(HTML(html))
# Out:
# <h1>Complex analysis has 2 connections!</h1><h3>Complex analysis</h3><p><p>For any complex function, the values <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle z}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mi>z</mi>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle z}</annotation>
# </semantics>
# </math></span><img alt="z" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/bf368e72c009decd9b6686ee84a375632e11de98" style="vertical-align: -0.338ex; width:1.088ex; height:1.676ex;"/></span> from the domain and their images <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle f(z)}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mi>f</mi>
# <mo stretchy="false">(</mo>
# <mi>z</mi>
# <mo stretchy="false">)</mo>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle f(z)}</annotation>
# </semantics>
# </math></span><img alt="f(z)" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d8dd568d570b390c337c0a911f0a1c5c214e8240" style="vertical-align: -0.838ex; width:4.176ex; height:2.843ex;"/></span> in the range may be separated into <a href="/wiki/Real_number" title="Real number">real</a> and <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary</a> parts:
# </p></p><h3>Cauchy–Riemann equations</h3><h3></h3><h1>Complex numbers has 2 connections!</h1><h3>Complex number</h3><p><p>In <a href="/wiki/Mathematics" title="Mathematics">mathematics</a>, a <b>complex number</b> is an element of a <a class="mw-redirect" href="/wiki/Number_system" title="Number system">number system</a> that extends the <a href="/wiki/Real_number" title="Real number">real numbers</a> with a specific element denoted <span class="texhtml mvar" style="font-style:italic;">i</span>, called the <a href="/wiki/Imaginary_unit" title="Imaginary unit">imaginary unit</a> and satisfying the <a href="/wiki/Equation" title="Equation">equation</a> <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle i^{2}=-1}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <msup>
# <mi>i</mi>
# <mrow class="MJX-TeXAtom-ORD">
# <mn>2</mn>
# </mrow>
# </msup>
# <mo>=</mo>
# <mo>−<!-- − --></mo>
# <mn>1</mn>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle i^{2}=-1}</annotation>
# </semantics>
# </math></span><img alt="{\displaystyle i^{2}=-1}" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/88e98a401d352e5037d5043028e2d7f449e83fa6" style="vertical-align: -0.505ex; width:7.926ex; height:2.843ex;"/></span>; every complex number can be expressed in the form <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle a+bi}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mi>a</mi>
# <mo>+</mo>
# <mi>b</mi>
# <mi>i</mi>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle a+bi}</annotation>
# </semantics>
# </math></span><img alt="a + bi" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/a92f853c2c9235c06be640b91b7c75e2a907cbda" style="vertical-align: -0.505ex; width:5.87ex; height:2.343ex;"/></span>, where <span class="texhtml mvar" style="font-style:italic;">a</span> and <span class="texhtml mvar" style="font-style:italic;">b</span> are real numbers. Because no real number satisfies the above equation, <span class="texhtml mvar" style="font-style:italic;">i</span> was called an <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a> by <a href="/wiki/Ren%C3%A9_Descartes" title="René Descartes">René Descartes</a>. For the complex number <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle a+bi}" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mi>a</mi>
# <mo>+</mo>
# <mi>b</mi>
# <mi>i</mi>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle a+bi}</annotation>
# </semantics>
# </math></span><img alt="a+bi" aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/a92f853c2c9235c06be640b91b7c75e2a907cbda" style="vertical-align: -0.505ex; width:5.87ex; height:2.343ex;"/></span>, <span class="texhtml mvar" style="font-style:italic;">a</span> is called the <b><style data-mw-deduplicate="TemplateStyles:r1023754711">.mw-parser-output .vanchor>:target~.vanchor-text{background-color:#b1d2ff}</style><span class="vanchor"><span id="real_part"></span><span class="vanchor-text">real part</span></span></b>, and <span class="texhtml mvar" style="font-style:italic;">b</span> is called the <b><link href="mw-data:TemplateStyles:r1023754711" rel="mw-deduplicated-inline-style"/><span class="vanchor"><span id="imaginary_part"></span><span class="vanchor-text">imaginary part</span></span></b>. The set of complex numbers is denoted by either of the symbols <span class="mwe-math-element"><span class="mwe-math-mathml-inline mwe-math-mathml-a11y" style="display: none;"><math alttext="{\displaystyle \mathbb {C} }" xmlns="http://www.w3.org/1998/Math/MathML">
# <semantics>
# <mrow class="MJX-TeXAtom-ORD">
# <mstyle displaystyle="true" scriptlevel="0">
# <mrow class="MJX-TeXAtom-ORD">
# <mi mathvariant="double-struck">C</mi>
# </mrow>
# </mstyle>
# </mrow>
# <annotation encoding="application/x-tex">{\displaystyle \mathbb {C} }</annotation>
# </semantics>
# </math></span><img alt="\mathbb {C} " aria-hidden="true" class="mwe-math-fallback-image-inline" src="https://wikimedia.org/api/rest_v1/media/math/render/svg/f9add4085095b9b6d28d045fd9c92c2c09f549a7" style="vertical-align: -0.338ex; width:1.678ex; height:2.176ex;"/></span> or <span class="texhtml"><b>C</b></span>. Despite the historical nomenclature "imaginary", complex numbers are regarded in the <a href="/wiki/Mathematical_sciences" title="Mathematical sciences">mathematical sciences</a> as just as "real" as the real numbers and are fundamental in many aspects of the scientific description of the natural world.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup><sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[a]</a></sup>
# </p></p><p><p>A real number <span class="texhtml mvar" style="font-style:italic;">a</span> can be regarded as a complex number <span class="texhtml"><i>a</i> + 0<i>i</i></span>, whose imaginary part is 0. A purely <a href="/wiki/Imaginary_number" title="Imaginary number">imaginary number</a> <span class="texhtml"><i>bi</i></span> is a complex number <span class="texhtml">0 + <i>bi</i></span>, whose real part is zero. As with polynomials, it is common to write <span class="texhtml mvar" style="font-style:italic;">a</span> for <span class="texhtml"><i>a</i> + 0<i>i</i></span> and <span class="texhtml"><i>bi</i></span> for <span class="texhtml">0 + <i>bi</i></span>. Moreover, when the imaginary part is negative, that is, <span class="texhtml"><i>b</i> = −<i>|b|</i> &lt; 0</span>, it is common to write <span class="texhtml"><i>a</i> − <i>|b|i</i></span> instead of <span class="texhtml"><i>a</i> + (−<i>|b|</i>)<i>i</i></span>; for example, for <span class="texhtml"><i>b</i> = −4</span>, <span

# %%
s = 'abc'
s += 'def'
s
# Out:
# 'abcdef'

# %%
imag_nums_0_200 = join_contents_from_json(["outputs/get_data_Imaginary_number_100.json", "outputs/get_data_Imaginary_number_100-105.json", "get_data_Imaginary_number_105-200"], "outputs/get_data_Imaginary_number_0-200.json")
# Out:
# writing your data to outputs/get_data_Imaginary_number_0-200.json

# %%
connections.analyze_categories(imag_nums_0_200)
# Out:
# {'category': [('Complex analysis',
#    {'count': 8,
#     'pages': ['Complex analysis',
#      'Cauchy–Riemann equations',
#      'Laurent series',
#      'Zeros and poles',
#      'Winding number',
#      'Complex plane',
#      'Isolated singularity',
#      'Contour integration']}),
#   ('Theorems in complex analysis',
#    {'count': 8,
#     'pages': ["Euler's formula",
#      'Riemann mapping theorem',
#      "Cauchy's integral theorem",
#      "Cauchy's integral formula",
#      'Residue theorem',
#      "Morera's theorem",
#      'Analyticity of holomorphic functions',
#      "Rouché's theorem"]}),
#   ('Complex numbers',
#    {'count': 6,
#     'pages': ['Complex number',
#      'Imaginary number',
#      'Imaginary unit',
#      'Complex conjugate',
#      'Complex plane',
#      'Quater-imaginary base']}),
#   ('Physical quantities',
#    {'count': 5,
#     'pages': ['Mass',
#      'Refractive index',
#      'Propagation constant',
#      'Electrical impedance',
#      'Admittance']}),
#   ('Analytic functions',
#    {'count': 4,
#     'pages': ['Holomorphic function',
#      'Analytic function',
#      'Residue theorem',
#      'Analyticity of holomorphic functions']}),
#   ('Quantum field theory',
#    {'count': 4,
#     'pages': ['CPT symmetry',
#      'Wick rotation',
#      'Spin–statistics theorem',
#      'Yukawa interaction']}),
#   ('Matrices',
#    {'count': 4,
#     'pages': ['Normal matrix',
#      'Skew-symmetric matrix',
#      'Hermitian matrix',
#      'Skew-Hermitian matrix']}),
#   ('Harmonic functions',
#    {'count': 3,
#     'pages': ['Cauchy–Riemann equations',
#      "Laplace's equation",
#      'Harmonic function']}),
#   ('Augustin-Louis Cauchy',
#    {'count': 3,
#     'pages': ['Cauchy–Riemann equations',
#      "Cauchy's integral theorem",
#      "Cauchy's integral formula"]}),
#   ('Elementary mathematics',
#    {'count': 3, 'pages': ['Integer', 'Natural number', 'Number line']}),
#   ('Integers',
#    {'count': 3, 'pages': ['Integer', 'Natural number', 'Cube (algebra)']}),
#   ('String theory',
#    {'count': 3,
#     'pages': ['Tachyon', 'Tachyon condensation', 'Bosonic string theory']}),
#   ('Electromagnetism',
#    {'count': 3,
#     'pages': ['Propagation constant', 'Evanescent field', 'Metamaterial']}),
#   ('Bernhard Riemann',
#    {'count': 2,
#     'pages': ['Cauchy–Riemann equations', 'Riemann mapping theorem']}),
#   ('Elementary algebra',
#    {'count': 2, 'pages': ['Elementary algebra', 'Nth root']}),
#   ('History of mathematics',
#    {'count': 2, 'pages': ['History of mathematics', 'René Descartes']}),
#   ('Ring theory', {'count': 2, 'pages': ['Integer', 'Formal power series']}),
#   ('Sets of real numbers',
#    {'count': 2, 'pages': ['Integer', 'Natural number']}),
#   ('Number theory',
#    {'count': 2, 'pages': ['Natural number', 'Cube (algebra)']}),
#   ('Numbers', {'count': 2, 'pages': ['Number', 'Mythical number']}),
#   ('History of algebra',
#    {'count': 2, 'pages': ['René Descartes', 'Theory of equations']}),
#   ('Tachyons', {'count': 2, 'pages': ['Tachyon', 'Tachyon condensation']}),
#   ('Equations',
#    {'count': 2, 'pages': ["Laplace's equation", 'Theory of equations']}),
#   ('Filter theory',
#    {'count': 2, 'pages': ['Propagation constant', 'Impedance matching']}),
#   ('Electrical resistance and conductance',
#    {'count': 2, 'pages': ['Electrical impedance', 'Admittance']}),
#   ('Matching (graph theory)',
#    {'count': 2, 'pages': ['Perfect matching', 'Matching (graph theory)']}),
#   ('Angle', {'count': 2, 'pages': ['Conformal map', 'Hyperbolic angle']}),
#   ('Abstract algebra',
#    {'count': 2, 'pages': ['Formal power series', 'Skew-Hermitian matrix']}),
#   ('Theorems in quantum mechanics',
#    {'count': 2, 'pages': ['CPT symmetry', 'Spin–statistics theorem']}),
#   ('Heat transfer', {'count': 2, 'pages': ['Advection', 'Heat equation']}),
#   ('Disambiguation pages', {'count': 2, 'pages': ['Lateral', 'Imaginary']}),
#   ('Metamaterials',
#    {'count': 2, 'pages': ['Evanescent field', 'Metamaterial']}),
#   ('Linear algebra',
#    {'count': 2, 'pages': ['Skew-Hermitian matrix', 'Sesquilinear form']}),
#   ('Composition algebras', {'count': 1, 'pages': ['Complex number']}),
#   ('Control theory', {'count': 1, 'pages': ['Control theory']}),
#   ('Control engineering', {'count': 1, 'pages': ['Control theory']}),
#   ('Computer engineering', {'count': 1, 'pages': ['Control theory']}),
#   ('Cybernetics', {'count': 1, 'pages': ['Control theory']}),
#   ('Partial differential equations',
#    {'count': 1, 'pages': ['Cauchy–Riemann equations']}),
#   ('Definition', {'count': 1, 'pages': ['Definition']}),
#   ('Philosophical logic', {'count': 1, 'pages': ['Definition']}),
#   ('Philosophy of language', {'count': 1, 'pages': ['Definition']}),
#   ('Semantics', {'count': 1, 'pages': ['Definition']}),
#   ('Linguistics terminology', {'count': 1, 'pages': ['Definition']}),
#   ('Mathematical terminology', {'count': 1, 'pages': ['Definition']}),
#   ('Concepts in logic', {'count': 1, 'pages': ['Definition']}),
#   ('Lexicography', {'count': 1, 'pages': ['Definition']}),
#   ('Meaning (philosophy of language)', {'count': 1, 'pages': ['Definition']}),
#   ('Analysis', {'count': 1, 'pages': ["Euler's formula"]}),
#   ('E (mathematical constant)', {'count': 1, 'pages': ["Euler's formula"]}),
#   ('Trigonometry', {'count': 1, 'pages': ["Euler's formula"]}),
#   ('Leonhard Euler', {'count': 1, 'pages': ["Euler's formula"]}),
#   ('Algebra', {'count': 1, 'pages': ['Elementary algebra']}),
#   ('Means', {'count': 1, 'pages': ['Geometric mean']}),
#   ('Non-Newtonian calculus', {'count': 1, 'pages': ['Geometric mean']}),
#   ('1501 births', {'count': 1, 'pages': ['Gerolamo Cardano']}),
#   ('1576 deaths', {'count': 1, 'pages': ['Gerolamo Cardano']}),
#   ('16th-century Latin-language writers',
#    {'count': 1, 'pages': ['Gerolamo Cardano']}),
#   ('16th-century Italian mathematicians',
#    {'count': 1, 'pages': ['Gerolamo Cardano']}),
#   ('16th-century Italian physicians',
#    {'count': 1, 'pages': ['Gerolamo Cardano']}),
#   ('Italian astrologers', {'count': 1, 'pages': ['Gerolamo Cardano']}),
#   ('16th-century astrologers', {'count': 1, 'pages': ['Gerolamo Cardano']}),
#   ('16th-century Italian inventors',
#    {'count': 1, 'pages': ['Gerolamo Cardano']}),
#   ('Physicians from Pavia', {'count': 1, 'pages': ['Gerolamo Cardano']}),
#   ('University of Pavia alumni', {'count': 1, 'pages': ['Gerolamo Cardano']}),
#   ('Scientists from Pavia', {'count': 1, 'pages': ['Gerolamo Cardano']}),
#   ('History of science by discipline',
#    {'count': 1, 'pages': ['History of mathematics']}),
#   ('Abelian group theory', {'count': 1, 'pages': ['Integer']}),
#   ('Elementary number theory', {'count': 1, 'pages': ['Integer']}),
#   ('Algebraic number theory', {'count': 1, 'pages': ['Integer']}),
#   ('Mass', {'count': 1, 'pages': ['Mass']}),
#   ('SI base quantities', {'count': 1, 'pages': ['Mass']}),
#   ('Moment (physics)', {'count': 1, 'pages': ['Mass']}),
#   ('Fractals', {'count': 1, 'pages': ['Mandelbrot set']}),
#   ('Complex dynamics', {'count': 1, 'pages': ['Mandelbrot set']}),
#   ('Cardinal numbers', {'count': 1, 'pages': ['Natural number']}),
#   ('Group theory', {'count': 1, 'pages': ['Number']}),
#   ('Mathematical objects', {'count': 1, 'pages': ['Number']}),
#   ('Polytopes', {'count': 1, 'pages': ['Polytope']}),
#   ('Real algebraic geometry', {'count': 1, 'pages': ['Polytope']}),
#   ('Polygons', {'count': 1, 'pages': ['Polygon']}),
#   ('Euclidean plane geometry', {'count': 1, 'pages': ['Polygon']}),
#   ('René Descartes', {'count': 1, 'pages': ['René Descartes']}),
#   ('Cartesianism', {'count': 1, 'pages': ['René Descartes']}),
#   ('1596 births', {'count': 1, 'pages': ['René Descartes']}),
#   ('1650 deaths', {'count': 1, 'pages': ['René Descartes']}),
#   ('17th-century French mathematicians',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('17th-century French philosophers',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('17th-century French scientists',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('17th-century French writers', {'count': 1, 'pages': ['René Descartes']}),
#   ('17th-century Latin-language writers',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('17th-century male writers', {'count': 1, 'pages': ['René Descartes']}),
#   ('Age of Enlightenment', {'count': 1, 'pages': ['René Descartes']}),
#   ('Aphorists', {'count': 1, 'pages': ['René Descartes']}),
#   ('Augustinian philosophers', {'count': 1, 'pages': ['René Descartes']}),
#   ('Burials at Saint-Germain-des-Prés (abbey)',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('Catholic philosophers', {'count': 1, 'pages': ['René Descartes']}),
#   ('French consciousness researchers and theorists',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('Constructed language creators', {'count': 1, 'pages': ['René Descartes']}),
#   ('Critics of animal rights', {'count': 1, 'pages': ['René Descartes']}),
#   ('Deaths from pneumonia in Sweden',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('Enlightenment philosophers', {'count': 1, 'pages': ['René Descartes']}),
#   ('Epistemologists', {'count': 1, 'pages': ['René Descartes']}),
#   ('Founders of philosophical traditions',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('French emigrants to the Dutch Republic',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('French ethicists', {'count': 1, 'pages': ['René Descartes']}),
#   ('French expatriates in Sweden', {'count': 1, 'pages': ['René Descartes']}),
#   ('French expatriates in the Dutch Republic',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('French logicians', {'count': 1, 'pages': ['René Descartes']}),
#   ('French mercenaries', {'count': 1, 'pages': ['René Descartes']}),
#   ('French music theorists', {'count': 1, 'pages': ['René Descartes']}),
#   ('French Roman Catholics', {'count': 1, 'pages': ['René Descartes']}),
#   ('Geometric algebra', {'count': 1, 'pages': ['René Descartes']}),
#   ('History of cartography', {'count': 1, 'pages': ['René Descartes']}),
#   ('History of education in Europe',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('History of ethics', {'count': 1, 'pages': ['René Descartes']}),
#   ('History of geometry', {'count': 1, 'pages': ['René Descartes']}),
#   ('History of logic', {'count': 1, 'pages': ['René Descartes']}),
#   ('History of measurement', {'count': 1, 'pages': ['René Descartes']}),
#   ('History of philosophy', {'count': 1, 'pages': ['René Descartes']}),
#   ('History of science', {'count': 1, 'pages': ['René Descartes']}),
#   ('Humor researchers', {'count': 1, 'pages': ['René Descartes']}),
#   ('Intellectual history', {'count': 1, 'pages': ['René Descartes']}),
#   ('Leiden University alumni', {'count': 1, 'pages': ['René Descartes']}),
#   ('Metaphilosophers', {'count': 1, 'pages': ['René Descartes']}),
#   ('Metaphysics writers', {'count': 1, 'pages': ['René Descartes']}),
#   ("Military personnel of the Thirty Years' War",
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('Mind–body problem', {'count': 1, 'pages': ['René Descartes']}),
#   ('Moral philosophers', {'count': 1, 'pages': ['René Descartes']}),
#   ('Natural philosophers', {'count': 1, 'pages': ['René Descartes']}),
#   ('Ontologists', {'count': 1, 'pages': ['René Descartes']}),
#   ('People from Indre-et-Loire', {'count': 1, 'pages': ['René Descartes']}),
#   ('People of the Age of Enlightenment',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophers of art', {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophers of culture', {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophers of education', {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophers of ethics and morality',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophers of history', {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophers of logic', {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophers of mathematics', {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophers of mind', {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophers of psychology', {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophers of science', {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophers of social science',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('Rationalists', {'count': 1, 'pages': ['René Descartes']}),
#   ('Rationality theorists', {'count': 1, 'pages': ['René Descartes']}),
#   ('Social critics', {'count': 1, 'pages': ['René Descartes']}),
#   ('Social philosophers', {'count': 1, 'pages': ['René Descartes']}),
#   ('Theorists on Western civilization',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('University of Poitiers alumni', {'count': 1, 'pages': ['René Descartes']}),
#   ('Western philosophy', {'count': 1, 'pages': ['René Descartes']}),
#   ('Writers about activism and social change',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('Writers about religion and science',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('Writers who illustrated their own writing',
#    {'count': 1, 'pages': ['René Descartes']}),
#   ('Dimensionless numbers', {'count': 1, 'pages': ['Refractive index']}),
#   ('Refraction', {'count': 1, 'pages': ['Refractive index']}),
#   ('Special relativity', {'count': 1, 'pages': ['Special relativity']}),
#   ('Albert Einstein', {'count': 1, 'pages': ['Special relativity']}),
#   ('Space', {'count': 1, 'pages': ['Space']}),
#   ('Geometry', {'count': 1, 'pages': ['Space']}),
#   ('Nature', {'count': 1, 'pages': ['Space']}),
#   ('Spacetime', {'count': 1, 'pages': ['Space']}),
#   ('Topology', {'count': 1, 'pages': ['Space']}),
#   ('Transcendental numbers', {'count': 1, 'pages': ['Transcendental number']}),
#   ('Hypothetical particles', {'count': 1, 'pages': ['Tachyon']}),
#   ('Time travel', {'count': 1, 'pages': ['Tachyon']}),
#   ('1572', {'count': 1, 'pages': ['1572']}),
#   ('1570s', {'count': 1, 'pages': ['1570s']}),
#   ('Elliptic partial differential equations',
#    {'count': 1, 'pages': ["Laplace's equation"]}),
#   ('Fourier analysis', {'count': 1, 'pages': ["Laplace's equation"]}),
#   ('Pierre-Simon Laplace', {'count': 1, 'pages': ["Laplace's equation"]}),
#   ('Quantized radio modulation modes',
#    {'count': 1, 'pages': ['Phase-shift keying']}),
#   ('Data transmission', {'count': 1, 'pages': ['Phase-shift keying']}),
#   ('Telecommunication theory',
#    {'count': 1, 'pages': ['Propagation constant']}),
#   ('Electromagnetic radiation',
#    {'count': 1, 'pages': ['Propagation constant']}),
#   ('Analog circuits', {'count': 1, 'pages': ['Propagation constant']}),
#   ('Image impedance filters', {'count': 1, 'pages': ['Propagation constant']}),
#   ('Antennas (radio)', {'count': 1, 'pages': ['Electrical impedance']}),
#   ('Philosophy of mathematics',
#    {'count': 1, 'pages': ['Philosophy of mathematics']}),
#   ('Mathematical analysis', {'count': 1, 'pages': ['Mathematical analysis']}),
#   ('Conformal mappings', {'count': 1, 'pages': ['Conformal map']}),
#   ('Riemannian geometry', {'count': 1, 'pages': ['Conformal map']}),
#   ('Map projections', {'count': 1, 'pages': ['Conformal map']}),
#   ('Algebraic numbers', {'count': 1, 'pages': ['Imaginary unit']}),
#   ('Quadratic irrational numbers', {'count': 1, 'pages': ['Imaginary unit']}),
#   ('Mathematical constants', {'count': 1, 'pages': ['Imaginary unit']}),
#   ('Enumerative combinatorics',
#    {'count': 1, 'pages': ['Formal power series']}),
#   ('Mathematical series', {'count': 1, 'pages': ['Formal power series']}),
#   ('Series expansions', {'count': 1, 'pages': ['Laurent series']}),
#   ('Hypothetical chemical elements',
#    {'count': 1, 'pages': ['Extended periodic table']}),
#   ('Periodic table', {'count': 1, 'pages': ['Extended periodic table']}),
#   ('Nuclear physics', {'count': 1, 'pages': ['Extended periodic table']}),
#   ('Meromorphic functions',
#    {'count': 1, 'pages': ['Residue (complex analysis)']}),
#   ('Broadcast engineering', {'count': 1, 'pages': ['Rayleigh fading']}),
#   ('Radio frequency propagation fading',
#    {'count': 1, 'pages': ['Rayleigh fading']}),
#   ('Surfaces', {'count': 1, 'pages': ['Spheroid']}),
#   ('Quadrics', {'count': 1, 'pages': ['Spheroid']}),
#   ('Algebraic topology', {'count': 1, 'pages': ['Winding number']}),
#   ('Differential geometry', {'count': 1, 'pages': ['Winding number']}),
#   ('Mathematics-related lists',
#    {'count': 1, 'pages': ['List of letters used in mathematics and science']}),
#   ('Physics-related lists',
#    {'count': 1, 'pages': ['List of letters used in mathematics and science']}),
#   ('Symmetry', {'count': 1, 'pages': ['CPT symmetry']}),
#   ('Vector calculus', {'count': 1, 'pages': ['Advection']}),
#   ('Atmospheric dynamics', {'count': 1, 'pages': ['Advection']}),
#   ('Conservation equations', {'count': 1, 'pages': ['Advection']}),
#   ('Equations of fluid dynamics', {'count': 1, 'pages': ['Advection']}),
#   ('Oceanography', {'count': 1, 'pages': ['Advection']}),
#   ('Convection', {'count': 1, 'pages': ['Advection']}),
#   ('Transport phenomena', {'count': 1, 'pages': ['Advection']}),
#   ('Diffusion', {'count': 1, 'pages': ['Heat equation']}),
#   ('Heat conduction', {'count': 1, 'pages': ['Heat equation']}),
#   ('Parabolic partial differential equations',
#    {'count': 1, 'pages': ['Heat equation']}),
#   ('Conic sections',
#    {'count': 1, 'pages': ['Matrix representation of conic sections']}),
#   ('Classical control theory', {'count': 1, 'pages': ['Complex plane']}),
#   ('Operations on numbers', {'count': 1, 'pages': ['Nth root']}),
#   ('Non-standard positional numeral systems',
#    {'count': 1, 'pages': ['Quater-imaginary base']}),
#   ('Donald Knuth', {'count': 1, 'pages': ['Quater-imaginary base']}),
#   ('Causality', {'count': 1, 'pages': ['Scientific law']}),
#   ('Empirical laws', {'count': 1, 'pages': ['Scientific law']}),
#   ('Metaphysics of science', {'count': 1, 'pages': ['Scientific law']}),
#   ('Philosophy of science', {'count': 1, 'pages': ['Scientific law']}),
#   ('Principles', {'count': 1, 'pages': ['Scientific law']}),
#   ('Science-related lists', {'count': 1, 'pages': ['Scientific law']}),
#   ('Scientific laws', {'count': 1, 'pages': ['Scientific law']}),
#   ('Scientific method', {'count': 1, 'pages': ['Scientific law']}),
#   ('Induction motors', {'count': 1, 'pages': ['Induction motor']}),
#   ('Electric motors', {'count': 1, 'pages': ['Induction motor']}),
#   ('AC motors', {'count': 1, 'pages': ['Induction motor']}),
#   ('Inventions by Nikola Tesla', {'count': 1, 'pages': ['Induction motor']}),
#   ('19th-century inventions', {'count': 1, 'pages': ['Induction motor']}),
#   ('Optics', {'count': 1, 'pages': ['Evanescent field']}),
#   ('Materials science', {'count': 1, 'pages': ['Evanescent field']}),
#   ('Nanotechnology', {'count': 1, 'pages': ['Evanescent field']}),
#   ('Quantum mechanics', {'count': 1, 'pages': ['Evanescent field']}),
#   ('Fictional angels',
#    {'count': 1, 'pages': ['Angels in Neon Genesis Evangelion']}),
#   ('Extraterrestrial species and races by work',
#    {'count': 1, 'pages': ['Angels in Neon Genesis Evangelion']}),
#   ('Neon Genesis Evangelion characters',
#    {'count': 1, 'pages': ['Angels in Neon Genesis Evangelion']}),
#   ('Kaiju', {'count': 1, 'pages': ['Angels in Neon Genesis Evangelion']}),
#   ('Neon Genesis Evangelion lists',
#    {'count': 1, 'pages': ['Angels in Neon Genesis Evangelion']}),
#   ('Mathematical manipulatives', {'count': 1, 'pages': ['Number line']}),
#   ('One-dimensional coordinate systems',
#    {'count': 1, 'pages': ['Number line']}),
#   ('Real numbers', {'count': 1, 'pages': ['Number line']}),
#   ('Topological spaces', {'count': 1, 'pages': ['Number line']}),
#   ('Statistical mechanics', {'count': 1, 'pages': ['Wick rotation']}),
#   ('Cyclotomic fields', {'count': 1, 'pages': ['Gaussian rational']}),
#   ('Number theory stubs', {'count': 1, 'pages': ['Gaussian rational']}),
#   ('Electronic design', {'count': 1, 'pages': ['Impedance matching']}),
#   ('Electronics concepts', {'count': 1, 'pages': ['Impedance matching']}),
#   ('Particle statistics', {'count': 1, 'pages': ['Spin–statistics theorem']}),
#   ('Statistical mechanics theorems',
#    {'count': 1, 'pages': ['Spin–statistics theorem']}),
#   ('Mathematics', {'count': 1, 'pages': ['Language of mathematics']}),
#   ('Language', {'count': 1, 'pages': ['Language of mathematics']}),
#   ('Elementary arithmetic', {'count': 1, 'pages': ['Cube (algebra)']}),
#   ('Figurate numbers', {'count': 1, 'pages': ['Cube (algebra)']}),
#   ('Integer sequences', {'count': 1, 'pages': ['Cube (algebra)']}),
#   ('Unary operations', {'count': 1, 'pages': ['Cube (algebra)']}),
#   ('Article proofs',
#    {'count': 1, 'pages': ['Analyticity of holomorphic functions']}),
#   ('Electrical engineering', {'count': 1, 'pages': ['Smith chart']}),
#   ('Charts', {'count': 1, 'pages': ['Smith chart']}),
#   ('Combinatorial optimization',
#    {'count': 1, 'pages': ['Matching (graph theory)']}),
#   ('Polynomial-time problems',
#    {'count': 1, 'pages': ['Matching (graph theory)']}),
#   ('Computational problems in graph theory',
#    {'count': 1, 'pages': ['Matching (graph theory)']}),
#   ('Polynomials', {'count': 1, 'pages': ['Theory of equations']}),
#   ('1572 in science', {'count': 1, 'pages': ['1572 in science']}),
#   ('16th century in science', {'count': 1, 'pages': ['1572 in science']}),
#   ('1570s in science', {'count': 1, 'pages': ['1572 in science']}),
#   ('String theory stubs', {'count': 1, 'pages': ['Tachyon condensation']}),
#   ('1980 in Idaho',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('1980 in Montana',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('1980 in Oregon',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('1980 in Washington (state)',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('1980 natural disasters in the United States',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('20th-century volcanic events',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Cascade Volcanoes',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Gifford Pinchot National Forest',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Mount St. Helens',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Natural disasters in Washington (state)',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Volcanism of Washington (state)',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Landslides in 1980',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('May 1980 events in the United States',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Megatsunamis',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('VEI-5 eruptions',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Volcanic eruptions in the United States',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Phreatic eruptions',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Plinian eruptions',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Peléan eruptions',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Volcanic tsunamis',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Loop quantum gravity', {'count': 1, 'pages': ['Ashtekar variables']}),
#   ('Data types', {'count': 1, 'pages': ['Numerical tower']}),
#   ('Functional analysis', {'count': 1, 'pages': ['Sesquilinear form']}),
#   ('Quantum gravity', {'count': 1, 'pages': ['Euclidean quantum gravity']}),
#   ('Elementary geometry', {'count': 1, 'pages': ['Line (geometry)']}),
#   ('Analytic geometry', {'count': 1, 'pages': ['Line (geometry)']}),
#   ('Mathematical concepts', {'count': 1, 'pages': ['Line (geometry)']}),
#   ('Types of polygons', {'count': 1, 'pages': ['Complex polygon']}),
#   ('Geometry stubs', {'count': 1, 'pages': ['Complex polygon']}),
#   ('Number stubs', {'count': 1, 'pages': ['Mythical number']}),
#   ('Differential calculus', {'count': 1, 'pages': ['Hyperbolic angle']}),
#   ('Integral calculus', {'count': 1, 'pages': ['Hyperbolic angle']}),
#   ('Standard Model', {'count': 1, 'pages': ['Yukawa interaction']}),
#   ('Electroweak theory', {'count': 1, 'pages': ['Yukawa interaction']}),
#   ('Theory of relativity', {'count': 1, 'pages': ['Rindler coordinates']}),
#   ('Coordinate charts in general relativity',
#    {'count': 1, 'pages': ['Rindler coordinates']}),
#   ('Acceleration', {'count': 1, 'pages': ['Rindler coordinates']})],
#  'navbox': [('Number systems',
#    {'count': 6,
#     'pages': ['Complex number',
#      'Imaginary number',
#      'Integer',
#      'Natural number',
#      'Number',
#      'Transcendental number']}),
#   ('Mathematics',
#    {'count': 5,
#     'pages': ['Control theory',
#      'Elementary algebra',
#      'History of mathematics',
#      'Philosophy of mathematics',
#      'Mathematical analysis']}),
#   ('Matrix classes',
#    {'count': 5,
#     'pages': ['Normal matrix',
#      'Skew-symmetric matrix',
#      'Matrix representation of conic sections',
#      'Hermitian matrix',
#      'Skew-Hermitian matrix']}),
#   ('Complex numbers',
#    {'count': 4,
#     'pages': ['Complex number',
#      'Imaginary number',
#      'Complex conjugate',
#      'Complex plane']}),
#   ('String theory',
#    {'count': 3,
#     'pages': ['Tachyon', 'Tachyon condensation', 'Bosonic string theory']}),
#   ('Sequences and series',
#    {'count': 3,
#     'pages': ['Formal power series', 'Laurent series', 'Cube (algebra)']}),
#   ('Major topics in mathematical analysis',
#    {'count': 2, 'pages': ['Complex analysis', 'Mathematical analysis']}),
#   ('Bernhard Riemann',
#    {'count': 2,
#     'pages': ['Cauchy–Riemann equations', 'Riemann mapping theorem']}),
#   ('Logic',
#    {'count': 2, 'pages': ['Definition', 'Philosophy of mathematics']}),
#   ('Classes of natural numbers',
#    {'count': 2, 'pages': ['Natural number', 'Cube (algebra)']}),
#   ('Number theory',
#    {'count': 2, 'pages': ['Number', 'Transcendental number']}),
#   ('Philosophy of science',
#    {'count': 2, 'pages': ['René Descartes', 'Scientific law']}),
#   ('Mathematical notation, symbols, and formulas',
#    {'count': 2,
#     'pages': ['List of letters used in mathematics and science',
#      'Language of mathematics']}),
#   ('Control theory', {'count': 1, 'pages': ['Control theory']}),
#   ('Subfields of and cyberneticians involved in cybernetics',
#    {'count': 1, 'pages': ['Control theory']}),
#   ('Systems science', {'count': 1, 'pages': ['Control theory']}),
#   ('Definition', {'count': 1, 'pages': ['Definition']}),
#   ('Aristotelian logic (syllogistic)', {'count': 1, 'pages': ['Definition']}),
#   ('Leonhard Euler', {'count': 1, 'pages': ["Euler's formula"]}),
#   ('Algebra', {'count': 1, 'pages': ['Elementary algebra']}),
#   ('Statistics', {'count': 1, 'pages': ['Geometric mean']}),
#   ('Indian mathematics', {'count': 1, 'pages': ['History of mathematics']}),
#   ('Mathematics in the medieval Islamic world',
#    {'count': 1, 'pages': ['History of mathematics']}),
#   ('History of science', {'count': 1, 'pages': ['History of mathematics']}),
#   ('Integers', {'count': 1, 'pages': ['Integer']}),
#   ('Rational numbers', {'count': 1, 'pages': ['Integer']}),
#   ('SI base quantities', {'count': 1, 'pages': ['Mass']}),
#   ('Classical mechanics SI units', {'count': 1, 'pages': ['Mass']}),
#   ('Fractal software', {'count': 1, 'pages': ['Mandelbrot set']}),
#   ('Fractals', {'count': 1, 'pages': ['Mandelbrot set']}),
#   ('Dimension', {'count': 1, 'pages': ['Polytope']}),
#   ('Polygons (List)', {'count': 1, 'pages': ['Polygon']}),
#   ('Age of Enlightenment', {'count': 1, 'pages': ['René Descartes']}),
#   ('Metaphysics', {'count': 1, 'pages': ['René Descartes']}),
#   ('Epistemology', {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophy of mind', {'count': 1, 'pages': ['René Descartes']}),
#   ('Philosophy of religion', {'count': 1, 'pages': ['René Descartes']}),
#   ('Consciousness', {'count': 1, 'pages': ['René Descartes']}),
#   ('Catholic philosophy', {'count': 1, 'pages': ['René Descartes']}),
#   ('History of Catholic theology', {'count': 1, 'pages': ['René Descartes']}),
#   ('Branches of physics', {'count': 1, 'pages': ['Special relativity']}),
#   ('Albert Einstein', {'count': 1, 'pages': ['Special relativity']}),
#   ('Relativity', {'count': 1, 'pages': ['Special relativity']}),
#   ('Tests of special relativity',
#    {'count': 1, 'pages': ['Special relativity']}),
#   ('Tensors', {'count': 1, 'pages': ['Special relativity']}),
#   ('Elements of nature', {'count': 1, 'pages': ['Space']}),
#   ('Irrational numbers', {'count': 1, 'pages': ['Transcendental number']}),
#   ('Particles in physics', {'count': 1, 'pages': ['Tachyon']}),
#   ('Philosophy', {'count': 1, 'pages': ['Philosophy of mathematics']}),
#   ('Mathematical logic', {'count': 1, 'pages': ['Philosophy of mathematics']}),
#   ('Industrial and applied mathematics',
#    {'count': 1, 'pages': ['Mathematical analysis']}),
#   ('Extended periodic table',
#    {'count': 1, 'pages': ['Extended periodic table']}),
#   ('Periodic table', {'count': 1, 'pages': ['Extended periodic table']}),
#   ('Analog and digital audio broadcasting',
#    {'count': 1, 'pages': ['Rayleigh fading']}),
#   ('Topology', {'count': 1, 'pages': ['Winding number']}),
#   ('C, P, and T symmetries', {'count': 1, 'pages': ['CPT symmetry']}),
#   ('Meteorological data and variables', {'count': 1, 'pages': ['Advection']}),
#   ('Hyperoperations', {'count': 1, 'pages': ['Nth root']}),
#   ('Donald Knuth', {'count': 1, 'pages': ['Quater-imaginary base']}),
#   ('Electric machines', {'count': 1, 'pages': ['Induction motor']}),
#   ('Nikola Tesla', {'count': 1, 'pages': ['Induction motor']}),
#   ('Neon Genesis Evangelion',
#    {'count': 1, 'pages': ['Angels in Neon Genesis Evangelion']}),
#   ('Real numbers', {'count': 1, 'pages': ['Number line']}),
#   ('Figurate numbers', {'count': 1, 'pages': ['Cube (algebra)']}),
#   ('Cascade Volcanoes',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('State of Washington',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Modern history of Oregon (1890–present)',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Natural disasters – list by death toll',
#    {'count': 1, 'pages': ['1980 eruption of Mount St. Helens']}),
#   ('Integrals', {'count': 1, 'pages': ['Contour integration']}),
#   ('Hilbert spaces', {'count': 1, 'pages': ['Sesquilinear form']}),
#   ('Emerging technologies', {'count': 1, 'pages': ['Metamaterial']}),
#   ('Theories of gravitation',
#    {'count': 1, 'pages': ['Euclidean quantum gravity']}),
#   ('Quantum gravity', {'count': 1, 'pages': ['Euclidean quantum gravity']}),
#   ('Quantum field theories', {'count': 1, 'pages': ['Yukawa interaction']})]}

# %% [markdown]
# #### Code to Implement and Remember

# %%
#useful information for quickly explaining what an article is.
wikipedia.summary("Euler's formula", sentences=2)
# Out:
# "Euler's formula, named after Leonhard Euler, is a mathematical formula in complex analysis that establishes the fundamental relationship between the trigonometric functions and the complex exponential function. Euler's formula states that for any real number x:\n\nwhere e is the base of the natural logarithm, i is the imaginary unit, and cos and sin are the trigonometric functions cosine and sine respectively."

# %% [markdown]
# ### Possible Readings/things to study

# %% [markdown]
# - https://www.wikidata.org/wiki/Wikidata:How_to_use_data_on_Wikimedia_projects
# - https://www.wikidata.org/wiki/Wikidata:Data_access
#     - great overview of what wikipedia tools I have to work with!
#     - Wikimedia action API will be used because I can grab up to 50 articles at once!
#         - link https://www.wikidata.org/w/api.php
#         - better link https://www.mediawiki.org/wiki/API:Categories#
#     - Linked data interface might be used because I can get the data needed in json
#     - Wikipedia dumps may be useful in the future because I can host my own instance of wikipedia data and query it as much as I want.
# - wikipedia python package https://wikipedia.readthedocs.io/en/latest/code.html#api
#
# A key component will be analyzing wikipeida categories and or the category trees for where an article fits in the grand scheme of things. https://en.wikipedia.org/wiki/Help:Category
#
# Possible algorithms to study
#  - https://ceur-ws.org/Vol-735/paper8.pdf
#  - https://medium.com/@RelcyEngineering/using-wikipedia-category-graph-for-semantic-understanding-5638c9897f8b

# %% [markdown]
# #### Possible algorithm
# 1. For a page, grab all categories and related categories from bottom of page.  first box is most specific, each category after that is higher level.  Note those categories and their structure somehow.  create a tree with this information.
# 2. loop through each page and grab the information.  count statistics on counts that overlap in each category.  do best to map them to parents/children.
#
# note: wikidata may be able to get me the category information with is_instance of but it may be too much data to deal with and it would be better to stick to the categories.  The effect of this is that I would need to grab each html page but I will want to do this to search for the keywords related to students interests anyways.
